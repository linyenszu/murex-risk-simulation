# %% [markdown]
# # 01 Data Simulation

# %% [markdown]
# Generate synthetic positions and organizational structure.

# %% [markdown]
# Download historical market data.

# %% [markdown]
# Inspect merged position-level inputs.
