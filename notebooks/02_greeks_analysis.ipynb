# %% [markdown]
# # 02 Greeks Analysis

# %% [markdown]
# Load merged positions with current prices.

# %% [markdown]
# Calculate NPV, Delta, Gamma, Vega, Theta, and Rho.

# %% [markdown]
# Explore option sensitivity outputs.
