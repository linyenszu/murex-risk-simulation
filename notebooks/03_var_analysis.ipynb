# %% [markdown]
# # 03 VaR Analysis

# %% [markdown]
# Build historical scenarios from market data.

# %% [markdown]
# Revalue the portfolio under each scenario.

# %% [markdown]
# Compute VaR, stressed VaR, and hierarchy-level reports.
